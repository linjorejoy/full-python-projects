# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '1.0.1'

# %%
df = pd.read_csv('scipy-2019-pandas-master\data\gapminder.tsv', sep="\t")

# %%
df
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (1704, 6)

# %%
df.size
# Out:
# 10224

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    1704 non-null   object
#  1   continent  1704 non-null   object
#  2   year       1704 non-null   int64
#  3   lifeExp    1704 non-null   float64
#  4   pop        1704 non-null   int64
#  5   gdpPercap  1704 non-null   float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 80.0+ KB

# %%
df.head(10)
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106
# 5  Afghanistan      Asia  1977   38.438  14880372  786.113360
# 6  Afghanistan      Asia  1982   39.854  12881816  978.011439
# 7  Afghanistan      Asia  1987   40.822  13867957  852.395945
# 8  Afghanistan      Asia  1992   41.674  16317921  649.341395
# 9  Afghanistan      Asia  1997   41.763  22227415  635.341351

# %%
a = df["country"] == "India"

# %%
a.empty
# Out:
# False

# %%
a.size
# Out:
# 1704

# %%
df.columns
# Out:
# Index(['country', 'continent', 'year', 'lifeExp', 'pop', 'gdpPercap'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1704, step=1)

# %%
df.dtypes
# Out:
# country       object
# continent     object
# year           int64
# lifeExp      float64
# pop            int64
# gdpPercap    float64
# dtype: object

# %%
country = df['country']
country
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 1699       Zimbabwe
# 1700       Zimbabwe
# 1701       Zimbabwe
# 1702       Zimbabwe
# 1703       Zimbabwe
# Name: country, Length: 1704, dtype: object

# %%
country = df[['country','continent']]

# %%
country
# Out:
#           country continent
# 0     Afghanistan      Asia
# 1     Afghanistan      Asia
# 2     Afghanistan      Asia
# 3     Afghanistan      Asia
# 4     Afghanistan      Asia
# ...           ...       ...
# 1699     Zimbabwe    Africa
# 1700     Zimbabwe    Africa
# 1701     Zimbabwe    Africa
# 1702     Zimbabwe    Africa
# 1703     Zimbabwe    Africa
#
# [1704 rows x 2 columns]

# %%
df
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
 df.loc[[0,5]]  
# only matches the 0 and 5 to index values
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 5  Afghanistan      Asia  1977   38.438  14880372  786.113360

# %%
# index position
df.iloc[[1,5,6,-1]]
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 5     Afghanistan      Asia  1977   38.438  14880372  786.113360
# 6     Afghanistan      Asia  1982   39.854  12881816  978.011439
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298

# %%
import numpy as np
df.iloc[np.arange(25)]
# Out:
#         country continent  year  lifeExp       pop    gdpPercap
# 0   Afghanistan      Asia  1952   28.801   8425333   779.445314
# 1   Afghanistan      Asia  1957   30.332   9240934   820.853030
# 2   Afghanistan      Asia  1962   31.997  10267083   853.100710
# 3   Afghanistan      Asia  1967   34.020  11537966   836.197138
# 4   Afghanistan      Asia  1972   36.088  13079460   739.981106
# 5   Afghanistan      Asia  1977   38.438  14880372   786.113360
# 6   Afghanistan      Asia  1982   39.854  12881816   978.011439
# 7   Afghanistan      Asia  1987   40.822  13867957   852.395945
# 8   Afghanistan      Asia  1992   41.674  16317921   649.341395
# 9   Afghanistan      Asia  1997   41.763  22227415   635.341351
# 10  Afghanistan      Asia  2002   42.129  25268405   726.734055
# 11  Afghanistan      Asia  2007   43.828  31889923   974.580338
# 12      Albania    Europe  1952   55.230   1282697  1601.056136
# 13      Albania    Europe  1957   59.280   1476505  1942.284244
# ...

# %%
subset = df.loc[:,['year','pop']]

# %%
subset
# Out:
#       year       pop
# 0     1952   8425333
# 1     1957   9240934
# 2     1962  10267083
# 3     1967  11537966
# 4     1972  13079460
# ...    ...       ...
# 1699  1987   9216418
# 1700  1992  10704340
# 1701  1997  11404948
# 1702  2002  11926563
# 1703  2007  12311143
#
# [1704 rows x 2 columns]

# %%
df.loc[1:5:2,['year','pop']]
# Out:
#    year       pop
# 1  1957   9240934
# 3  1967  11537966
# 5  1977  14880372

# %%
df.iloc[696:708:1,0:]
# Out:
#     country continent  year  lifeExp         pop    gdpPercap
# 696   India      Asia  1952   37.373   372000000   546.565749
# 697   India      Asia  1957   40.249   409000000   590.061996
# 698   India      Asia  1962   43.605   454000000   658.347151
# 699   India      Asia  1967   47.193   506000000   700.770611
# 700   India      Asia  1972   50.651   567000000   724.032527
# 701   India      Asia  1977   54.208   634000000   813.337323
# 702   India      Asia  1982   56.596   708000000   855.723538
# 703   India      Asia  1987   58.553   788000000   976.512676
# 704   India      Asia  1992   60.223   872000000  1164.406809
# 705   India      Asia  1997   61.765   959000000  1458.817442
# 706   India      Asia  2002   62.879  1034172547  1746.769454
# 707   India      Asia  2007   64.698  1110396331  2452.210407

# %%
df.loc[df['country'] == 'India']
# Out:
#     country continent  year  lifeExp         pop    gdpPercap
# 696   India      Asia  1952   37.373   372000000   546.565749
# 697   India      Asia  1957   40.249   409000000   590.061996
# 698   India      Asia  1962   43.605   454000000   658.347151
# 699   India      Asia  1967   47.193   506000000   700.770611
# 700   India      Asia  1972   50.651   567000000   724.032527
# 701   India      Asia  1977   54.208   634000000   813.337323
# 702   India      Asia  1982   56.596   708000000   855.723538
# 703   India      Asia  1987   58.553   788000000   976.512676
# 704   India      Asia  1992   60.223   872000000  1164.406809
# 705   India      Asia  1997   61.765   959000000  1458.817442
# 706   India      Asia  2002   62.879  1034172547  1746.769454
# 707   India      Asia  2007   64.698  1110396331  2452.210407

# %%
# Since this is bitwise comparison we need brackets for multiple conditions
df.loc[(df['country'] == 'India') & (df['year'] == 1992)]
# Out:
#     country continent  year  lifeExp        pop    gdpPercap
# 704   India      Asia  1992   60.223  872000000  1164.406809

# %%
df_year = df.groupby('year').mean()
df_year
# Out:
#         lifeExp           pop     gdpPercap
# year
# 1952  49.057620  1.695040e+07   3725.276046
# 1957  51.507401  1.876341e+07   4299.408345
# 1962  53.609249  2.042101e+07   4725.812342
# 1967  55.678290  2.265830e+07   5483.653047
# 1972  57.647386  2.518998e+07   6770.082815
# 1977  59.570157  2.767638e+07   7313.166421
# 1982  61.533197  3.020730e+07   7518.901673
# 1987  63.212613  3.303857e+07   7900.920218
# 1992  64.160338  3.599092e+07   8158.608521
# 1997  65.014676  3.883947e+07   9090.175363
# 2002  65.694923  4.145759e+07   9917.848365
# 2007  67.007423  4.402122e+07  11680.071820

# %%
df_other = df.groupby(['year','country']).mean()
df_other.head(15)
# Out:
#                              lifeExp       pop     gdpPercap
# year country
# 1952 Afghanistan              28.801   8425333    779.445314
#      Albania                  55.230   1282697   1601.056136
#      Algeria                  43.077   9279525   2449.008185
#      Angola                   30.015   4232095   3520.610273
#      Argentina                62.485  17876956   5911.315053
#      Australia                69.120   8691212  10039.595640
#      Austria                  66.800   6927772   6137.076492
#      Bahrain                  50.939    120447   9867.084765
#      Bangladesh               37.484  46886859    684.244172
#      Belgium                  68.000   8730405   8343.105127
#      Benin                    38.223   1738315   1062.752200
#      Bolivia                  40.414   2883315   2677.326347
#      Bosnia and Herzegovina   53.820   2791000    973.533195
#      Botswana                 47.622    442308    851.241141
# ...

# %%
df_other = df.groupby(['country','year']).mean()
df_other.head(15)
# Out:
#                   lifeExp       pop    gdpPercap
# country     year
# Afghanistan 1952   28.801   8425333   779.445314
#             1957   30.332   9240934   820.853030
#             1962   31.997  10267083   853.100710
#             1967   34.020  11537966   836.197138
#             1972   36.088  13079460   739.981106
#             1977   38.438  14880372   786.113360
#             1982   39.854  12881816   978.011439
#             1987   40.822  13867957   852.395945
#             1992   41.674  16317921   649.341395
#             1997   41.763  22227415   635.341351
#             2002   42.129  25268405   726.734055
#             2007   43.828  31889923   974.580338
# Albania     1952   55.230   1282697  1601.056136
#             1957   59.280   1476505  1942.284244
#             1962   64.820   1728137  2312.888958

# %%
df.groupby(['year'])['lifeExp'].mean()
# Out:
# year
# 1952    49.057620
# 1957    51.507401
# 1962    53.609249
# 1967    55.678290
# 1972    57.647386
# 1977    59.570157
# 1982    61.533197
# 1987    63.212613
# 1992    64.160338
# 1997    65.014676
# 2002    65.694923
# 2007    67.007423
# Name: lifeExp, dtype: float64

# %%
df.groupby(['year'])['lifeExp'].agg(np.mean)
# Out:
# year
# 1952    49.057620
# 1957    51.507401
# 1962    53.609249
# 1967    55.678290
# 1972    57.647386
# 1977    59.570157
# 1982    61.533197
# 1987    63.212613
# 1992    64.160338
# 1997    65.014676
# 2002    65.694923
# 2007    67.007423
# Name: lifeExp, dtype: float64

# %%
# pass any function even user defined which return one value
df.groupby(['year'])['lifeExp'].agg(np.std)
# Out:
# year
# 1952    12.225956
# 1957    12.231286
# 1962    12.097245
# 1967    11.718858
# 1972    11.381953
# 1977    11.227229
# 1982    10.770618
# 1987    10.556285
# 1992    11.227380
# 1997    11.559439
# 2002    12.279823
# 2007    12.073021
# Name: lifeExp, dtype: float64

# %%
df.groupby(['year','continent'])[['lifeExp','gdpPercap']].agg(np.std)
# Out:
#                   lifeExp     gdpPercap
# year continent
# 1952 Africa      5.151581    982.952116
#      Americas    9.326082   3001.727522
#      Asia        9.291751  18634.890865
#      Europe      6.361088   3114.060493
#      Oceania     0.190919    365.560078
# 1957 Africa      5.620123   1134.508918
#      Americas    9.033192   3312.381083
#      Asia        9.635429  19506.515959
#      Europe      5.295805   3677.950146
#      Oceania     0.049497    917.644806
# 1962 Africa      5.875364   1461.839189
#      Americas    8.503544   3421.740569
#      Asia        9.820632  16415.857196
#      Europe      4.302500   4199.193906
#      Oceania     0.219203    677.727301
# 1967 Africa      6.082673   2847.717603
#      Americas    7.909171   4160.885560
#      Asia        9.650965  14062.591362
#      Europe      3.799728   4724.983889
#      Oceania     0.296985     43.986086
# 1972 Africa      6.416258   3286.853884
#      Americas    7.323017   4754.404329
# ...

# %%
import seaborn as sns
